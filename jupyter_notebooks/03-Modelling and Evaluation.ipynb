# %% [markdown]
# # Modeling and Evaluation Notebook

# %% [markdown]
# ## Objectives
#
# *   Answer business requirement 2:
#     * The client is interested to tell whether a given cell contains malaria parasite or not.
#
#
# ## Inputs
#
# * inputs/malaria_dataset/cell_images/train
# * inputs/malaria_dataset/cell_images/test
# * inputs/malaria_dataset/cell_images/validation
# * image shape embeddings
#
# ## Outputs
# * Images distribution plot in train, validation, and test set
# * Image augmentation
# * Class indices to change prediction inference in labels
# * Machine learning model creation and training
# * Save model
# * Learning curve plot for model performance
# * Model evaluation on pickle file
# * Prediction on the random image file
#
#
#
#
# ## Additional Comments | Insights | Conclusions

# %%
pip install pandas
# Out:
# Requirement already satisfied: pandas in /workspace/.pip-modules/lib/python3.8/site-packages (1.1.2)
# Requirement already satisfied: numpy>=1.15.4 in /workspace/.pip-modules/lib/python3.8/site-packages (from pandas) (1.23.2)
# Requirement already satisfied: python-dateutil>=2.7.3 in /home/gitpod/.pyenv/versions/3.8.12/lib/python3.8/site-packages (from pandas) (2.8.2)
# Requirement already satisfied: pytz>=2017.2 in /workspace/.pip-modules/lib/python3.8/site-packages (from pandas) (2022.2.1)
# Requirement already satisfied: six>=1.5 in /workspace/.pip-modules/lib/python3.8/site-packages (from python-dateutil>=2.7.3->pandas) (1.15.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
import os
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from matplotlib.image import imread

# %%
# Set Working Directory

# %%
cwd= os.getcwd()

# %%
os.chdir('/workspace/Instant-Mildew-Detector')
print("You set a new current directory")
# Out:
# You set a new current directory

# %%
work_dir = os.getcwd()
work_dir
# Out:
# '/workspace/Instant-Mildew-Detector'

# %% [markdown]
# ## Set input directories

# %%
my_data_dir = 'inputs/cherry_leaves/cherry-leaves'
train_path = my_data_dir + '/train'
val_path = my_data_dir + '/validation'
test_path = my_data_dir + '/test'

# %% [markdown]
# ## Set output directory

# %%
version = 'v1'
file_path = f'outputs/{version}'

if 'outputs' in os.listdir(work_dir) and version in os.listdir(work_dir + '/outputs'):
  print('Old version is already available create a new version.')
  pass
else:
  os.makedirs(name=file_path)
# Out:
# Old version is already available create a new version.

# %% [markdown]
# ## Set labels

# %%
labels = os.listdir(train_path)

print(
    f"Project Labels: {labels}"
    )
# Out:
# Project Labels: ['healthy', 'powdery_mildew']

# %% [markdown]
# ## Set image shape

# %% [markdown]
# ## Set image shape

# %%
pip install joblib
# Out:
# Requirement already satisfied: joblib in /workspace/.pip-modules/lib/python3.8/site-packages (1.1.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
## Import saved image shape embedding
import joblib
version = 'v1'
image_shape = joblib.load(filename=f"outputs/{version}/image_shape.pkl")
image_shape
# Out:
# (256, 256, 3)

# %% [markdown]
# # Number of images in train, test and validation data

# %%
df_freq = pd.DataFrame([]) 
for folder in ['train', 'validation', 'test']:
  for label in labels:
    df_freq = df_freq.append(
        pd.Series(data={'Set': folder,
                        'Label': label,
                        'Frequency':int(len(os.listdir(my_data_dir+'/'+ folder + '/' + label)))}
                  ),
                  ignore_index=True
        )
    
    print(f"* {folder} - {label}: {len(os.listdir(my_data_dir+'/'+ folder + '/' + label))} images")

print("\n")
sns.set_style("whitegrid")
plt.figure(figsize=(8,5))
sns.barplot(data=df_freq, x='Set', y='Frequency', hue='Label')
plt.savefig(f'{file_path}/labels_distribution.png', bbox_inches='tight', dpi=150)
plt.show()
# Out:
# * train - healthy: 1472 images
# * train - powdery_mildew: 1472 images
# * validation - healthy: 210 images
# * validation - powdery_mildew: 210 images
# * test - healthy: 422 images
# * test - powdery_mildew: 422 images

# %% [markdown]
# # Image data augmentation

# %% [markdown]
# ### ImageDataGenerator

# %%
pip install tensorflow
# Out:
# Requirement already satisfied: tensorflow in /workspace/.pip-modules/lib/python3.8/site-packages (2.9.2)
# Requirement already satisfied: tensorboard<2.10,>=2.9 in /workspace/.pip-modules/lib/python3.8/site-packages (from tensorflow) (2.9.1)
# Requirement already satisfied: termcolor>=1.1.0 in /workspace/.pip-modules/lib/python3.8/site-packages (from tensorflow) (1.1.0)
# Requirement already satisfied: grpcio<2.0,>=1.24.3 in /workspace/.pip-modules/lib/python3.8/site-packages (from tensorflow) (1.48.1)
# Requirement already satisfied: google-pasta>=0.1.1 in /workspace/.pip-modules/lib/python3.8/site-packages (from tensorflow) (0.2.0)
# Requirement already satisfied: h5py>=2.9.0 in /workspace/.pip-modules/lib/python3.8/site-packages (from tensorflow) (3.1.0)
# Requirement already satisfied: gast<=0.4.0,>=0.2.1 in /workspace/.pip-modules/lib/python3.8/site-packages (from tensorflow) (0.4.0)
# Requirement already satisfied: six>=1.12.0 in /workspace/.pip-modules/lib/python3.8/site-packages (from tensorflow) (1.15.0)
# Requirement already satisfied: opt-einsum>=2.3.2 in /workspace/.pip-modules/lib/python3.8/site-packages (from tensorflow) (3.3.0)
# Requirement already satisfied: tensorflow-estimator<2.10.0,>=2.9.0rc0 in /workspace/.pip-modules/lib/python3.8/site-packages (from tensorflow) (2.9.0)
# Requirement already satisfied: protobuf<3.20,>=3.9.2 in /workspace/.pip-modules/lib/python3.8/site-packages (from tensorflow) (3.19.4)
# Requirement already satisfied: typing-extensions>=3.6.6 in /workspace/.pip-modules/lib/python3.8/site-packages (from tensorflow) (3.7.4.3)
# Requirement already satisfied: absl-py>=1.0.0 in /workspace/.pip-modules/lib/python3.8/site-packages (from tensorflow) (1.2.0)
# Requirement already satisfied: tensorflow-io-gcs-filesystem>=0.23.1 in /workspace/.pip-modules/lib/python3.8/site-packages (from tensorflow) (0.26.0)
# Requirement already satisfied: wrapt>=1.11.0 in /workspace/.pip-modules/lib/python3.8/site-packages (from tensorflow) (1.12.1)
# Requirement already satisfied: keras<2.10.0,>=2.9.0rc0 in /workspace/.pip-modules/lib/python3.8/site-packages (from tensorflow) (2.9.0)
# Requirement already satisfied: keras-preprocessing>=1.1.1 in /workspace/.pip-modules/lib/python3.8/site-packages (from tensorflow) (1.1.2)
# Requirement already satisfied: flatbuffers<2,>=1.12 in /workspace/.pip-modules/lib/python3.8/site-packages (from tensorflow) (1.12)
# Requirement already satisfied: packaging in /home/gitpod/.pyenv/versions/3.8.12/lib/python3.8/site-packages (from tensorflow) (21.3)
# Requirement already satisfied: setuptools in /home/gitpod/.pyenv/versions/3.8.12/lib/python3.8/site-packages (from tensorflow) (65.3.0)
# Requirement already satisfied: numpy>=1.20 in /workspace/.pip-modules/lib/python3.8/site-packages (from tensorflow) (1.23.2)
# Requirement already satisfied: libclang>=13.0.0 in /workspace/.pip-modules/lib/python3.8/site-packages (from tensorflow) (14.0.6)
# Requirement already satisfied: astunparse>=1.6.0 in /workspace/.pip-modules/lib/python3.8/site-packages (from tensorflow) (1.6.3)
# Requirement already satisfied: wheel<1.0,>=0.23.0 in /home/gitpod/.pyenv/versions/3.8.12/lib/python3.8/site-packages (from astunparse>=1.6.0->tensorflow) (0.37.1)
# Requirement already satisfied: markdown>=2.6.8 in /workspace/.pip-modules/lib/python3.8/site-packages (from tensorboard<2.10,>=2.9->tensorflow) (3.4.1)
# Requirement already satisfied: werkzeug>=1.0.1 in /workspace/.pip-modules/lib/python3.8/site-packages (from tensorboard<2.10,>=2.9->tensorflow) (2.2.2)
# Requirement already satisfied: google-auth-oauthlib<0.5,>=0.4.1 in /workspace/.pip-modules/lib/python3.8/site-packages (from tensorboard<2.10,>=2.9->tensorflow) (0.4.6)
# Requirement already satisfied: tensorboard-data-server<0.7.0,>=0.6.0 in /workspace/.pip-modules/lib/python3.8/site-packages (from tensorboard<2.10,>=2.9->tensorflow) (0.6.1)
# Requirement already satisfied: google-auth<3,>=1.6.3 in /workspace/.pip-modules/lib/python3.8/site-packages (from tensorboard<2.10,>=2.9->tensorflow) (2.11.0)
# Requirement already satisfied: tensorboard-plugin-wit>=1.6.0 in /workspace/.pip-modules/lib/python3.8/site-packages (from tensorboard<2.10,>=2.9->tensorflow) (1.8.1)
# Requirement already satisfied: requests<3,>=2.21.0 in /home/gitpod/.pyenv/versions/3.8.12/lib/python3.8/site-packages (from tensorboard<2.10,>=2.9->tensorflow) (2.28.1)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in /home/gitpod/.pyenv/versions/3.8.12/lib/python3.8/site-packages (from packaging->tensorflow) (3.0.9)
# Requirement already satisfied: rsa<5,>=3.1.4 in /workspace/.pip-modules/lib/python3.8/site-packages (from google-auth<3,>=1.6.3->tensorboard<2.10,>=2.9->tensorflow) (4.9)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /workspace/.pip-modules/lib/python3.8/site-packages (from google-auth<3,>=1.6.3->tensorboard<2.10,>=2.9->tensorflow) (0.2.8)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in /workspace/.pip-modules/lib/python3.8/site-packages (from google-auth<3,>=1.6.3->tensorboard<2.10,>=2.9->tensorflow) (5.2.0)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in /workspace/.pip-modules/lib/python3.8/site-packages (from google-auth-oauthlib<0.5,>=0.4.1->tensorboard<2.10,>=2.9->tensorflow) (1.3.1)
# Requirement already satisfied: importlib-metadata>=4.4 in /home/gitpod/.pyenv/versions/3.8.12/lib/python3.8/site-packages (from markdown>=2.6.8->tensorboard<2.10,>=2.9->tensorflow) (4.12.0)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /home/gitpod/.pyenv/versions/3.8.12/lib/python3.8/site-packages (from requests<3,>=2.21.0->tensorboard<2.10,>=2.9->tensorflow) (1.26.12)
# Requirement already satisfied: idna<4,>=2.5 in /home/gitpod/.pyenv/versions/3.8.12/lib/python3.8/site-packages (from requests<3,>=2.21.0->tensorboard<2.10,>=2.9->tensorflow) (3.3)
# Requirement already satisfied: certifi>=2017.4.17 in /home/gitpod/.pyenv/versions/3.8.12/lib/python3.8/site-packages (from requests<3,>=2.21.0->tensorboard<2.10,>=2.9->tensorflow) (2022.6.15)
# Requirement already satisfied: charset-normalizer<3,>=2 in /home/gitpod/.pyenv/versions/3.8.12/lib/python3.8/site-packages (from requests<3,>=2.21.0->tensorboard<2.10,>=2.9->tensorflow) (2.1.1)
# Requirement already satisfied: MarkupSafe>=2.1.1 in /home/gitpod/.pyenv/versions/3.8.12/lib/python3.8/site-packages (from werkzeug>=1.0.1->tensorboard<2.10,>=2.9->tensorflow) (2.1.1)
# Requirement already satisfied: zipp>=0.5 in /home/gitpod/.pyenv/versions/3.8.12/lib/python3.8/site-packages (from importlib-metadata>=4.4->markdown>=2.6.8->tensorboard<2.10,>=2.9->tensorflow) (3.8.1)
# Requirement already satisfied: pyasn1<0.5.0,>=0.4.6 in /workspace/.pip-modules/lib/python3.8/site-packages (from pyasn1-modules>=0.2.1->google-auth<3,>=1.6.3->tensorboard<2.10,>=2.9->tensorflow) (0.4.8)
# Requirement already satisfied: oauthlib>=3.0.0 in /workspace/.pip-modules/lib/python3.8/site-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib<0.5,>=0.4.1->tensorboard<2.10,>=2.9->tensorflow) (3.2.0)
# Note: you may need to restart the kernel to use updated packages.

# %% [markdown]
# * ### Intiatize ImageDataGenerator

# %%
from tensorflow.keras.preprocessing.image import ImageDataGenerator

# %%
augmented_image_data = ImageDataGenerator(rotation_range=20,
                                   width_shift_range=0.10, 
                                   height_shift_range=0.10,
                                   shear_range=0.1,
                                   zoom_range=0.1,
                                   horizontal_flip=True,
                                   vertical_flip=True,
                                   fill_mode='nearest',
                                   rescale=1./255
                              )

# %% [markdown]
# * ### Augment training image dataset

# %%
batch_size = 20 # Set batch size
train_set = augmented_image_data.flow_from_directory(train_path,
                                              target_size=image_shape[:2],
                                              color_mode='rgb',
                                              batch_size=batch_size,
                                              class_mode='binary',
                                              shuffle=True
                                              )

train_set.class_indices
# Out:
# Found 2944 images belonging to 2 classes.
# {'healthy': 0, 'powdery_mildew': 1}

# %% [markdown]
# * ### Augment validation image dataset

# %%
validation_set = ImageDataGenerator(rescale=1./255).flow_from_directory(val_path,
                                                          target_size=image_shape[:2],
                                                          color_mode='rgb',
                                                          batch_size=batch_size,
                                                          class_mode='binary',
                                                          shuffle=False
                                                          )

validation_set.class_indices
# Out:
# Found 420 images belonging to 2 classes.
# {'healthy': 0, 'powdery_mildew': 1}

# %% [markdown]
# * ### Augment test image dataset

# %%
test_set = ImageDataGenerator(rescale=1./255).flow_from_directory(test_path,
                                                    target_size=image_shape[:2],
                                                    color_mode='rgb',
                                                    batch_size=batch_size,
                                                    class_mode='binary',
                                                    shuffle=False
                                                    )

test_set.class_indices
# Out:
# Found 844 images belonging to 2 classes.
# {'healthy': 0, 'powdery_mildew': 1}

# %% [markdown]
# ## Plot augmented training image

# %%
for _ in range(3):
    img, label = train_set.next()
    print(img.shape)   #  (1,256,256,3)
    plt.imshow(img[0])
    plt.show()
# Out:
# (20, 256, 256, 3)
# (20, 256, 256, 3)
# (20, 256, 256, 3)

# %% [markdown]
# ## Save class_indices

# %%
joblib.dump(value=train_set.class_indices ,
            filename=f"{file_path}/class_indices.pkl")
# Out:
# ['outputs/v1/class_indices.pkl']

# %% [markdown]
# ---

# %% [markdown]
# # Model creation

# %% [markdown]
# ---

# %% [markdown]
# ## ML model

# %% [markdown]
# * ### Import model packages

# %%
pip install tensorflow
# Out:
# Requirement already satisfied: tensorflow in /workspace/.pip-modules/lib/python3.8/site-packages (2.9.2)
# Requirement already satisfied: flatbuffers<2,>=1.12 in /workspace/.pip-modules/lib/python3.8/site-packages (from tensorflow) (1.12)
# Requirement already satisfied: packaging in /home/gitpod/.pyenv/versions/3.8.12/lib/python3.8/site-packages (from tensorflow) (21.3)
# Requirement already satisfied: numpy>=1.20 in /workspace/.pip-modules/lib/python3.8/site-packages (from tensorflow) (1.23.2)
# Requirement already satisfied: gast<=0.4.0,>=0.2.1 in /workspace/.pip-modules/lib/python3.8/site-packages (from tensorflow) (0.4.0)
# Requirement already satisfied: tensorflow-estimator<2.10.0,>=2.9.0rc0 in /workspace/.pip-modules/lib/python3.8/site-packages (from tensorflow) (2.9.0)
# Requirement already satisfied: libclang>=13.0.0 in /workspace/.pip-modules/lib/python3.8/site-packages (from tensorflow) (14.0.6)
# Requirement already satisfied: keras-preprocessing>=1.1.1 in /workspace/.pip-modules/lib/python3.8/site-packages (from tensorflow) (1.1.2)
# Requirement already satisfied: setuptools in /home/gitpod/.pyenv/versions/3.8.12/lib/python3.8/site-packages (from tensorflow) (65.3.0)
# Requirement already satisfied: h5py>=2.9.0 in /workspace/.pip-modules/lib/python3.8/site-packages (from tensorflow) (3.1.0)
# Requirement already satisfied: six>=1.12.0 in /workspace/.pip-modules/lib/python3.8/site-packages (from tensorflow) (1.15.0)
# Requirement already satisfied: grpcio<2.0,>=1.24.3 in /workspace/.pip-modules/lib/python3.8/site-packages (from tensorflow) (1.48.1)
# Requirement already satisfied: google-pasta>=0.1.1 in /workspace/.pip-modules/lib/python3.8/site-packages (from tensorflow) (0.2.0)
# Requirement already satisfied: keras<2.10.0,>=2.9.0rc0 in /workspace/.pip-modules/lib/python3.8/site-packages (from tensorflow) (2.9.0)
# Requirement already satisfied: absl-py>=1.0.0 in /workspace/.pip-modules/lib/python3.8/site-packages (from tensorflow) (1.2.0)
# Requirement already satisfied: tensorboard<2.10,>=2.9 in /workspace/.pip-modules/lib/python3.8/site-packages (from tensorflow) (2.9.1)
# Requirement already satisfied: termcolor>=1.1.0 in /workspace/.pip-modules/lib/python3.8/site-packages (from tensorflow) (1.1.0)
# Requirement already satisfied: tensorflow-io-gcs-filesystem>=0.23.1 in /workspace/.pip-modules/lib/python3.8/site-packages (from tensorflow) (0.26.0)
# Requirement already satisfied: typing-extensions>=3.6.6 in /workspace/.pip-modules/lib/python3.8/site-packages (from tensorflow) (3.7.4.3)
# Requirement already satisfied: protobuf<3.20,>=3.9.2 in /workspace/.pip-modules/lib/python3.8/site-packages (from tensorflow) (3.19.4)
# Requirement already satisfied: opt-einsum>=2.3.2 in /workspace/.pip-modules/lib/python3.8/site-packages (from tensorflow) (3.3.0)
# Requirement already satisfied: astunparse>=1.6.0 in /workspace/.pip-modules/lib/python3.8/site-packages (from tensorflow) (1.6.3)
# Requirement already satisfied: wrapt>=1.11.0 in /workspace/.pip-modules/lib/python3.8/site-packages (from tensorflow) (1.12.1)
# Requirement already satisfied: wheel<1.0,>=0.23.0 in /home/gitpod/.pyenv/versions/3.8.12/lib/python3.8/site-packages (from astunparse>=1.6.0->tensorflow) (0.37.1)
# Requirement already satisfied: tensorboard-plugin-wit>=1.6.0 in /workspace/.pip-modules/lib/python3.8/site-packages (from tensorboard<2.10,>=2.9->tensorflow) (1.8.1)
# Requirement already satisfied: tensorboard-data-server<0.7.0,>=0.6.0 in /workspace/.pip-modules/lib/python3.8/site-packages (from tensorboard<2.10,>=2.9->tensorflow) (0.6.1)
# Requirement already satisfied: requests<3,>=2.21.0 in /home/gitpod/.pyenv/versions/3.8.12/lib/python3.8/site-packages (from tensorboard<2.10,>=2.9->tensorflow) (2.28.1)
# Requirement already satisfied: markdown>=2.6.8 in /workspace/.pip-modules/lib/python3.8/site-packages (from tensorboard<2.10,>=2.9->tensorflow) (3.4.1)
# Requirement already satisfied: google-auth<3,>=1.6.3 in /workspace/.pip-modules/lib/python3.8/site-packages (from tensorboard<2.10,>=2.9->tensorflow) (2.11.0)
# Requirement already satisfied: google-auth-oauthlib<0.5,>=0.4.1 in /workspace/.pip-modules/lib/python3.8/site-packages (from tensorboard<2.10,>=2.9->tensorflow) (0.4.6)
# Requirement already satisfied: werkzeug>=1.0.1 in /workspace/.pip-modules/lib/python3.8/site-packages (from tensorboard<2.10,>=2.9->tensorflow) (2.2.2)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in /home/gitpod/.pyenv/versions/3.8.12/lib/python3.8/site-packages (from packaging->tensorflow) (3.0.9)
# Requirement already satisfied: rsa<5,>=3.1.4 in /workspace/.pip-modules/lib/python3.8/site-packages (from google-auth<3,>=1.6.3->tensorboard<2.10,>=2.9->tensorflow) (4.9)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in /workspace/.pip-modules/lib/python3.8/site-packages (from google-auth<3,>=1.6.3->tensorboard<2.10,>=2.9->tensorflow) (5.2.0)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /workspace/.pip-modules/lib/python3.8/site-packages (from google-auth<3,>=1.6.3->tensorboard<2.10,>=2.9->tensorflow) (0.2.8)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in /workspace/.pip-modules/lib/python3.8/site-packages (from google-auth-oauthlib<0.5,>=0.4.1->tensorboard<2.10,>=2.9->tensorflow) (1.3.1)
# Requirement already satisfied: importlib-metadata>=4.4 in /home/gitpod/.pyenv/versions/3.8.12/lib/python3.8/site-packages (from markdown>=2.6.8->tensorboard<2.10,>=2.9->tensorflow) (4.12.0)
# Requirement already satisfied: idna<4,>=2.5 in /home/gitpod/.pyenv/versions/3.8.12/lib/python3.8/site-packages (from requests<3,>=2.21.0->tensorboard<2.10,>=2.9->tensorflow) (3.3)
# Requirement already satisfied: certifi>=2017.4.17 in /home/gitpod/.pyenv/versions/3.8.12/lib/python3.8/site-packages (from requests<3,>=2.21.0->tensorboard<2.10,>=2.9->tensorflow) (2022.6.15)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /home/gitpod/.pyenv/versions/3.8.12/lib/python3.8/site-packages (from requests<3,>=2.21.0->tensorboard<2.10,>=2.9->tensorflow) (1.26.12)
# Requirement already satisfied: charset-normalizer<3,>=2 in /home/gitpod/.pyenv/versions/3.8.12/lib/python3.8/site-packages (from requests<3,>=2.21.0->tensorboard<2.10,>=2.9->tensorflow) (2.1.1)
# Requirement already satisfied: MarkupSafe>=2.1.1 in /home/gitpod/.pyenv/versions/3.8.12/lib/python3.8/site-packages (from werkzeug>=1.0.1->tensorboard<2.10,>=2.9->tensorflow) (2.1.1)
# Requirement already satisfied: zipp>=0.5 in /home/gitpod/.pyenv/versions/3.8.12/lib/python3.8/site-packages (from importlib-metadata>=4.4->markdown>=2.6.8->tensorboard<2.10,>=2.9->tensorflow) (3.8.1)
# Requirement already satisfied: pyasn1<0.5.0,>=0.4.6 in /workspace/.pip-modules/lib/python3.8/site-packages (from pyasn1-modules>=0.2.1->google-auth<3,>=1.6.3->tensorboard<2.10,>=2.9->tensorflow) (0.4.8)
# Requirement already satisfied: oauthlib>=3.0.0 in /workspace/.pip-modules/lib/python3.8/site-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib<0.5,>=0.4.1->tensorboard<2.10,>=2.9->tensorflow) (3.2.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Activation, Dropout, Flatten, Dense, Conv2D, MaxPooling2D

# %% [markdown]
# * ### Model

# %%
def create_tf_model():
    model = Sequential()

    model.add(Conv2D(filters=32, kernel_size=(3,3),input_shape=image_shape, activation='relu',))
    model.add(MaxPooling2D(pool_size=(2, 2)))

    model.add(Conv2D(filters=64, kernel_size=(3,3),input_shape=image_shape, activation='relu',))
    model.add(MaxPooling2D(pool_size=(2, 2)))

    model.add(Conv2D(filters=64, kernel_size=(3,3),input_shape=image_shape, activation='relu',))
    model.add(MaxPooling2D(pool_size=(2, 2)))

    model.add(Flatten())
    model.add(Dense(128, activation = 'relu'))

    model.add(Dropout(0.5))
    model.add(Dense(1, activation = 'sigmoid'))

    model.compile(loss='binary_crossentropy',
                  optimizer='adam',
                  metrics=['accuracy'])
    
    return model

# %% [markdown]
# * ### Model Summary

# %%
create_tf_model().summary()
# Out:
# 2022-09-21 20:50:58.182401: W tensorflow/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libcuda.so.1'; dlerror: libcuda.so.1: cannot open shared object file: No such file or directory
# 2022-09-21 20:50:58.182461: W tensorflow/stream_executor/cuda/cuda_driver.cc:269] failed call to cuInit: UNKNOWN ERROR (303)
# 2022-09-21 20:50:58.182493: I tensorflow/stream_executor/cuda/cuda_diagnostics.cc:156] kernel driver does not appear to be running on this host (haimanota-instantmildew-a8whz0owstw): /proc/driver/nvidia/version does not exist
# 2022-09-21 20:50:58.182814: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /workspace/Instant-Mildew-Detector/jupyter_notebooks/03-Modelling and Evaluation.ipynb Cell 48 in <cell line: 1>()
# ----> <a href='vscode-notebook-cell://haimanota-instantmildew-a8whz0owstw.ws-eu64.gitpod.io/workspace/Instant-Mildew-Detector/jupyter_notebooks/03-Modelling%20and%20Evaluation.ipynb#X65sdnNjb2RlLXJlbW90ZQ%3D%3D?line=0'>1</a> create_tf_model().summary()
#
# /workspace/Instant-Mildew-Detector/jupyter_notebooks/03-Modelling and Evaluation.ipynb Cell 48 in create_tf_model()
#       <a href='vscode-notebook-cell://haimanota-instantmildew-a8whz0owstw.ws-eu64.gitpod.io/workspace/Instant-Mildew-Detector/jupyter_notebooks/03-Modelling%20and%20Evaluation.ipynb#X65sdnNjb2RlLXJlbW90ZQ%3D%3D?line=0'>1</a> def create_tf_model():
#       <a href='vscode-notebook-cell://haimanota-instantmildew-a8whz0owstw.ws-eu64.gitpod.io/workspace/Instant-Mildew-Detector/jupyter_notebooks/03-Modelling%20and%20Evaluation.ipynb#X65sdnNjb2RlLXJlbW90ZQ%3D%3D?line=1'>2</a>     model = Sequential()
# ----> <a href='vscode-notebook-cell://haimanota-instantmildew-a8whz0owstw.ws-eu64.gitpod.io/workspace/Instant-Mildew-Detector/jupyter_notebooks/03-Modelling%20and%20Evaluation.ipynb#X65sdnNjb2RlLXJlbW90ZQ%3D%3D?line=3'>4</a>     model.add(Conv2D(filters=32, kernel_size=(3,3),input_shape=image_shape, activation='relu',))
#       <a href='vscode-notebook-cell://haimanota-instantmildew-a8whz0owstw.ws-eu64.gitpod.io/workspace/Instant-Mildew-Detector/jupyter_notebooks/03-Modelling%20and%20Evaluation.ipynb#X65sdnNjb2RlLXJlbW90ZQ%3D%3D?line=4'>5</a>     model.add(MaxPooling2D(pool_size=(2, 2)))
#       <a href='vscode-notebook-cell://haimanota-instantmildew-a8whz0owstw.ws-eu64.gitpod.io/workspace/Instant-Mildew-Detector/jupyter_notebooks/03-Modelling%20and%20Evaluation.ipynb#X65sdnNjb2RlLXJlbW90ZQ%3D%3D?line=6'>7</a>     model.add(Conv2D(filters=64, kernel_size=(3,3),input_shape=image_shape, activation='relu',))
#
# NameError: name 'image_shape' is not defined

# %% [markdown]
# * ### Early Stopping

# %%
from tensorflow.keras.callbacks import EarlyStopping
early_stop = EarlyStopping(monitor='val_loss',patience=3)

# %% [markdown]
# ## Fit model for model training

# %%
model = create_tf_model()
model.fit(train_set,
          epochs=25,
          steps_per_epoch = len(train_set.classes) // batch_size,
          validation_data=validation_set,
          callbacks=[early_stop],
          verbose=1
          )
# Out:
# Epoch 1/25
# 147/147 [==============================] - 101s 683ms/step - loss: 0.3897 - accuracy: 0.8163 - val_loss: 0.5329 - val_accuracy: 0.7976
# Epoch 2/25
# 147/147 [==============================] - 98s 668ms/step - loss: 0.0783 - accuracy: 0.9733 - val_loss: 0.0268 - val_accuracy: 0.9929
# Epoch 3/25
# 147/147 [==============================] - 99s 670ms/step - loss: 0.0337 - accuracy: 0.9901 - val_loss: 0.0097 - val_accuracy: 0.9952
# Epoch 4/25
# 147/147 [==============================] - 132s 900ms/step - loss: 0.0249 - accuracy: 0.9935 - val_loss: 0.0224 - val_accuracy: 0.9952
# Epoch 5/25
# 147/147 [==============================] - 192s 1s/step - loss: 0.0477 - accuracy: 0.9867 - val_loss: 0.0077 - val_accuracy: 0.9976
# Epoch 6/25
# 147/147 [==============================] - 247s 2s/step - loss: 0.0320 - accuracy: 0.9877 - val_loss: 0.0214 - val_accuracy: 0.9929
# Epoch 7/25
# 147/147 [==============================] - 151s 1s/step - loss: 0.0305 - accuracy: 0.9897 - val_loss: 0.0100 - val_accuracy: 0.9976
# Epoch 8/25
# 147/147 [==============================] - 153s 1s/step - loss: 0.0594 - accuracy: 0.9812 - val_loss: 0.0019 - val_accuracy: 1.0000
# Epoch 9/25
# 147/147 [==============================] - 142s 966ms/step - loss: 0.0106 - accuracy: 0.9976 - val_loss: 5.3258e-04 - val_accuracy: 1.0000
# Epoch 10/25
# 147/147 [==============================] - 152s 1s/step - loss: 0.0079 - accuracy: 0.9969 - val_loss: 0.0135 - val_accuracy: 0.9952
# Epoch 11/25
#  70/147 [=============>................] - ETA: 1:25 - loss: 0.0046 - accuracy: 0.9986

# %% [markdown]
# ---

# %% [markdown]
# ## Save model

# %%
model.save('outputs/ver1/mildew_detector_model.h5')

# %% [markdown]
# ## Model learning curve

# %%
losses = pd.DataFrame(model.history.history)

sns.set_style("whitegrid")
losses[['loss','val_loss']].plot(style='.-')
plt.title("Loss")
plt.savefig(f'{file_path}/model_training_losses.png', bbox_inches='tight', dpi=150)
plt.show()

print("\n")
losses[['accuracy','val_accuracy']].plot(style='.-')
plt.title("Accuracy")
plt.savefig(f'{file_path}/model_training_acc.png', bbox_inches='tight', dpi=150)
plt.show()

# %% [markdown]
# # Model Performace

# %% [markdown]
# ## Model learning curve

# %%
pip install pandas
# Out:
# Requirement already satisfied: pandas in /workspace/.pip-modules/lib/python3.8/site-packages (1.1.2)
# Requirement already satisfied: numpy>=1.15.4 in /workspace/.pip-modules/lib/python3.8/site-packages (from pandas) (1.23.2)
# Requirement already satisfied: python-dateutil>=2.7.3 in /home/gitpod/.pyenv/versions/3.8.12/lib/python3.8/site-packages (from pandas) (2.8.2)
# Requirement already satisfied: pytz>=2017.2 in /workspace/.pip-modules/lib/python3.8/site-packages (from pandas) (2022.2.1)
# Requirement already satisfied: six>=1.5 in /workspace/.pip-modules/lib/python3.8/site-packages (from python-dateutil>=2.7.3->pandas) (1.15.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
losses = pd.DataFrame(model.history.history)

sns.set_style("whitegrid")
losses[['loss','val_loss']].plot(style='.-')
plt.title("Loss")
plt.savefig(f'{file_path}/model_training_losses.png', bbox_inches='tight', dpi=150)
plt.show()

print("\n")
losses[['accuracy','val_accuracy']].plot(style='.-')
plt.title("Accuracy")
plt.savefig(f'{file_path}/model_training_acc.png', bbox_inches='tight', dpi=150)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /workspace/Instant-Mildew-Detector/jupyter_notebooks/03-Modelling and Evaluation.ipynb Cell 63 in <cell line: 1>()
# ----> <a href='vscode-notebook-cell://haimanota-instantmildew-a8whz0owstw.ws-eu64.gitpod.io/workspace/Instant-Mildew-Detector/jupyter_notebooks/03-Modelling%20and%20Evaluation.ipynb#Y115sdnNjb2RlLXJlbW90ZQ%3D%3D?line=0'>1</a> losses = pd.DataFrame(model.history.history)
#       <a href='vscode-notebook-cell://haimanota-instantmildew-a8whz0owstw.ws-eu64.gitpod.io/workspace/Instant-Mildew-Detector/jupyter_notebooks/03-Modelling%20and%20Evaluation.ipynb#Y115sdnNjb2RlLXJlbW90ZQ%3D%3D?line=2'>3</a> sns.set_style("whitegrid")
#       <a href='vscode-notebook-cell://haimanota-instantmildew-a8whz0owstw.ws-eu64.gitpod.io/workspace/Instant-Mildew-Detector/jupyter_notebooks/03-Modelling%20and%20Evaluation.ipynb#Y115sdnNjb2RlLXJlbW90ZQ%3D%3D?line=3'>4</a> losses[['loss','val_loss']].plot(style='.-')
#
# NameError: name 'pd' is not defined

# %% [markdown]
# ## Model Evaluation

# %%
pip install keras
# Out:
# Requirement already satisfied: keras in /workspace/.pip-modules/lib/python3.8/site-packages (2.9.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
evaluation = model.evaluate(test_set)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /workspace/Instant-Mildew-Detector/jupyter_notebooks/03-Modelling and Evaluation.ipynb Cell 66 in <cell line: 1>()
# ----> <a href='vscode-notebook-cell://haimanota-instantmildew-a8whz0owstw.ws-eu64.gitpod.io/workspace/Instant-Mildew-Detector/jupyter_notebooks/03-Modelling%20and%20Evaluation.ipynb#Y122sdnNjb2RlLXJlbW90ZQ%3D%3D?line=0'>1</a> evaluation = model.evaluate(test_set)
#
# NameError: name 'model' is not defined

# %% [markdown]
# ### Save evaluation pickle

# %%
joblib.dump(value=evaluation ,
            filename=f"outputs/v1/evaluation.pkl")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /workspace/Instant-Mildew-Detector/jupyter_notebooks/03-Modelling and Evaluation.ipynb Cell 68 in <cell line: 1>()
# ----> <a href='vscode-notebook-cell://haimanota-instantmildew-a8whz0owstw.ws-eu64.gitpod.io/workspace/Instant-Mildew-Detector/jupyter_notebooks/03-Modelling%20and%20Evaluation.ipynb#Y124sdnNjb2RlLXJlbW90ZQ%3D%3D?line=0'>1</a> joblib.dump(value=evaluation ,
#       <a href='vscode-notebook-cell://haimanota-instantmildew-a8whz0owstw.ws-eu64.gitpod.io/workspace/Instant-Mildew-Detector/jupyter_notebooks/03-Modelling%20and%20Evaluation.ipynb#Y124sdnNjb2RlLXJlbW90ZQ%3D%3D?line=1'>2</a>             filename=f"outputs/v1/evaluation.pkl")
#
# NameError: name 'joblib' is not defined

# %% [markdown]
# ## Predict on new data

# %% [markdown]
# Load a random image as PIL

# %%
from tensorflow.keras.preprocessing import image

pointer = 66 
label = labels[0] # select Uninfected or Parasitized

pil_image = image.load_img(test_path + '/'+ label + '/'+ os.listdir(test_path+'/'+ label)[pointer],
                          target_size=image_shape, color_mode='rgb')
print(f'Image shape: {pil_image.size}, Image mode: {pil_image.mode}')
pil_image
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /workspace/Instant-Mildew-Detector/jupyter_notebooks/03-Modelling and Evaluation.ipynb Cell 71 in <cell line: 4>()
#       <a href='vscode-notebook-cell://haimanota-instantmildew-a8whz0owstw.ws-eu64.gitpod.io/workspace/Instant-Mildew-Detector/jupyter_notebooks/03-Modelling%20and%20Evaluation.ipynb#Y132sdnNjb2RlLXJlbW90ZQ%3D%3D?line=0'>1</a> from tensorflow.keras.preprocessing import image
#       <a href='vscode-notebook-cell://haimanota-instantmildew-a8whz0owstw.ws-eu64.gitpod.io/workspace/Instant-Mildew-Detector/jupyter_notebooks/03-Modelling%20and%20Evaluation.ipynb#Y132sdnNjb2RlLXJlbW90ZQ%3D%3D?line=2'>3</a> pointer = 66
# ----> <a href='vscode-notebook-cell://haimanota-instantmildew-a8whz0owstw.ws-eu64.gitpod.io/workspace/Instant-Mildew-Detector/jupyter_notebooks/03-Modelling%20and%20Evaluation.ipynb#Y132sdnNjb2RlLXJlbW90ZQ%3D%3D?line=3'>4</a> label = labels[0] # select Uninfected or Parasitized
#       <a href='vscode-notebook-cell://haimanota-instantmildew-a8whz0owstw.ws-eu64.gitpod.io/workspace/Instant-Mildew-Detector/jupyter_notebooks/03-Modelling%20and%20Evaluation.ipynb#Y132sdnNjb2RlLXJlbW90ZQ%3D%3D?line=5'>6</a> pil_image = image.load_img(test_path + '/'+ label + '/'+ os.listdir(test_path+'/'+ label)[pointer],
#       <a href='vscode-notebook-cell://haimanota-instantmildew-a8whz0owstw.ws-eu64.gitpod.io/workspace/Instant-Mildew-Detector/jupyter_notebooks/03-Modelling%20and%20Evaluation.ipynb#Y132sdnNjb2RlLXJlbW90ZQ%3D%3D?line=6'>7</a>                           target_size=image_shape, color_mode='rgb')
#       <a href='vscode-notebook-cell://haimanota-instantmildew-a8whz0owstw.ws-eu64.gitpod.io/workspace/Instant-Mildew-Detector/jupyter_notebooks/03-Modelling%20and%20Evaluation.ipynb#Y132sdnNjb2RlLXJlbW90ZQ%3D%3D?line=7'>8</a> print(f'Image shape: {pil_image.size}, Image mode: {pil_image.mode}')
#
# NameError: name 'labels' is not defined

# %% [markdown]
# Convert image to array and prepare for prediction

# %%
my_image = image.img_to_array(pil_image)
my_image = np.expand_dims(my_image, axis=0)/255
print(my_image.shape)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /workspace/Instant-Mildew-Detector/jupyter_notebooks/03-Modelling and Evaluation.ipynb Cell 73 in <cell line: 1>()
# ----> <a href='vscode-notebook-cell://haimanota-instantmildew-a8whz0owstw.ws-eu64.gitpod.io/workspace/Instant-Mildew-Detector/jupyter_notebooks/03-Modelling%20and%20Evaluation.ipynb#Y134sdnNjb2RlLXJlbW90ZQ%3D%3D?line=0'>1</a> my_image = image.img_to_array(pil_image)
#       <a href='vscode-notebook-cell://haimanota-instantmildew-a8whz0owstw.ws-eu64.gitpod.io/workspace/Instant-Mildew-Detector/jupyter_notebooks/03-Modelling%20and%20Evaluation.ipynb#Y134sdnNjb2RlLXJlbW90ZQ%3D%3D?line=1'>2</a> my_image = np.expand_dims(my_image, axis=0)/255
#       <a href='vscode-notebook-cell://haimanota-instantmildew-a8whz0owstw.ws-eu64.gitpod.io/workspace/Instant-Mildew-Detector/jupyter_notebooks/03-Modelling%20and%20Evaluation.ipynb#Y134sdnNjb2RlLXJlbW90ZQ%3D%3D?line=2'>3</a> print(my_image.shape)
#
# NameError: name 'pil_image' is not defined

# %% [markdown]
# Predict class probabilities

# %%
pred_proba = model.predict(my_image)[0,0]

target_map = {v: k for k, v in train_set.class_indices.items()}
pred_class =  target_map[pred_proba > 0.5]  

if pred_class == target_map[0]: pred_proba = 1 - pred_proba

print(pred_proba)
print(pred_class)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /workspace/Instant-Mildew-Detector/jupyter_notebooks/03-Modelling and Evaluation.ipynb Cell 75 in <cell line: 1>()
# ----> <a href='vscode-notebook-cell://haimanota-instantmildew-a8whz0owstw.ws-eu64.gitpod.io/workspace/Instant-Mildew-Detector/jupyter_notebooks/03-Modelling%20and%20Evaluation.ipynb#Y136sdnNjb2RlLXJlbW90ZQ%3D%3D?line=0'>1</a> pred_proba = model.predict(my_image)[0,0]
#       <a href='vscode-notebook-cell://haimanota-instantmildew-a8whz0owstw.ws-eu64.gitpod.io/workspace/Instant-Mildew-Detector/jupyter_notebooks/03-Modelling%20and%20Evaluation.ipynb#Y136sdnNjb2RlLXJlbW90ZQ%3D%3D?line=2'>3</a> target_map = {v: k for k, v in train_set.class_indices.items()}
#       <a href='vscode-notebook-cell://haimanota-instantmildew-a8whz0owstw.ws-eu64.gitpod.io/workspace/Instant-Mildew-Detector/jupyter_notebooks/03-Modelling%20and%20Evaluation.ipynb#Y136sdnNjb2RlLXJlbW90ZQ%3D%3D?line=3'>4</a> pred_class =  target_map[pred_proba > 0.5]
#
# NameError: name 'model' is not defined

# %% [markdown]
# # Push files to Repo

# %% [markdown]
# ## Push generated/new files from this Session to GitHub repo

# %%
# !cat .gitignore

# %%
# !git commit -am " Add new plots and test model performance"
# Out:
# [main 2e7e265]  Add new plots and test model performance
#  1 file changed, 674 insertions(+), 59 deletions(-)

# %%
# !git push
# Out:
# Enumerating objects: 7, done.
# Counting objects: 100% (7/7), done.
# Delta compression using up to 16 threads
# Compressing objects: 100% (4/4), done.
# Writing objects: 100% (4/4), 521.17 KiB | 10.64 MiB/s, done.
# Total 4 (delta 2), reused 0 (delta 0), pack-reused 0
# remote: Resolving deltas: 100% (2/2), completed with 2 local objects.
# To https://github.com/HaimanotA/Instant-Mildew-Detector.git
#    0aba2ab..2e7e265  main -> main
